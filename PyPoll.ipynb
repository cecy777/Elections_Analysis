# %%
# Create a filename variable to a direct or indirect path to the file.
file_to_save = os.path.join("analysis", "election_analysis.txt")

# Use the open statement to open the file as a text file.
outfile = open(file_to_save, "w")
# Write some data to the file.
outfile.write("Hello World")

# Add our dependencies.
import csv
import os
# Assign a variable to load a file from a path.
file_to_load = os.path.join("Resources", "election_results.csv")
# Assign a variable to save the file to a path.
file_to_save = os.path.join("analysis", "election_analysis.txt")

# Open the election results and read the file.
with open(file_to_load) as election_data:

# To do: read and analyze the data here.
# Read the file object with the reader function.
   file_reader = csv.reader(election_data)

# Print each row in the CSV file.
for row in file_reader:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\cecyr\OneDrive\Desktop\Class Work\Individual Projects\Elections_Analysis\PyPoll.py in <cell line: 25>()
#      <a href='file:///c%3A/Users/cecyr/OneDrive/Desktop/Class%20Work/Individual%20Projects/Elections_Analysis/PyPoll.py?line=21'>22</a>    file_reader = csv.reader(election_data)
#      <a href='file:///c%3A/Users/cecyr/OneDrive/Desktop/Class%20Work/Individual%20Projects/Elections_Analysis/PyPoll.py?line=23'>24</a> # Print each row in the CSV file.
# ---> <a href='file:///c%3A/Users/cecyr/OneDrive/Desktop/Class%20Work/Individual%20Projects/Elections_Analysis/PyPoll.py?line=24'>25</a> for row in file_reader:
#      <a href='file:///c%3A/Users/cecyr/OneDrive/Desktop/Class%20Work/Individual%20Projects/Elections_Analysis/PyPoll.py?line=25'>26</a>         print(row)
#
# ValueError: I/O operation on closed file.

# %%
# Add our dependencies.
import csv
import os
# Assign a variable to load a file from a path.
file_to_load = os.path.join("Resources", "election_results.csv")
# Assign a variable to save the file to a path.
file_to_save = os.path.join("analysis", "election_analysis.txt")

# Open the election results and read the file.
with open(file_to_load) as election_data:
    file_reader = csv.reader(election_data)

    # Read and print the header row.
    headers = next(file_reader)
    print(headers)
# Out:
# ['Ballot ID', 'County', 'Candidate']
